# %%
1+2
# Out:
# 3

# %%
1-3
# Out:
# -2

# %%
2**4
# Out:
# 16

# %%
'Hi! my name is..'
# Out:
# 'Hi! my name is..'

# %%
x='hello'
print(x)
# Out:
# hello

# %%
print('hello')
# Out:
# hello

# %%
name='Harshul'
print('My name is {}'.format(name))
# Out:
# My name is Harshul

# %%
name='Harshul'
age=18
subject='PFAT'
print('Age is {1}\nName is {0}\nSubject is {2}'.format(name,age,subject))
# Out:
# Age is 18
# Name is Harshul
# Subject is PFAT

# %%
#List
[0,1,2]
# Out:
# [0, 1, 2]

# %%
['hi',0,1]
# Out:
# ['hi', 0, 1]

# %%
my_list=[0,1,2]

# %%
my_list.extend([3,4])
print(my_list)
# Out:
# [0, 1, 2, 3, 4]

# %%
my_list.append(5)
print(my_list)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
my_list[0]
# Out:
# 0

# %%
my_list[-1]
# Out:
# 5

# %%
my_list[0:4]
# Out:
# [0, 1, 2, 3]

# %%
my_list[0:2]
# Out:
# [0, 1]

# %%
my_list[3:]
# Out:
# [3, 4, 5]

# %%
nested=[0,1,[2,3]]

# %%
nested
# Out:
# [0, 1, [2, 3]]

# %%
nested[2][0]
# Out:
# 2

# %%
nested[0]
# Out:
# 0

# %%
#dictionaries 
d={'key':10,'key2':'seconditem'}

# %%
d['key2']
# Out:
# 'seconditem'

# %%
#tuples
tuples=(1,2,3)
tuples[0]
# Out:
# 1

# %%
my_list[0]='watermelon'
my_list
# Out:
# ['watermelon', 1, 2, 3, 4, 5]

# %%
# tuples[0]='watermelon'

# %%
#set
{1,2,3,4,5}
# Out:
# {1, 2, 3, 4, 5}

# %%
set([1,1,2,3,3,2,2,2,4,4,5,5,6,6,6,4])
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
import math
math.sqrt(100)
# Out:
# 10.0

# %%
y='hellooo'
y[0]
# Out:
# 'h'

# %%
#comparison operators

# %%
1<2
# Out:
# True

# %%
1>=4
# Out:
# False

# %%
1=='2'
# Out:
# False

# %%
1!=1
# Out:
# False

# %%
(1==2)and(1==1)
# Out:
# False

# %%
([1,2]==1)
# Out:
# False

# %%
([1,2][0]==1)
# Out:
# True

# %%
if (1!=2):
    print('hello')
# Out:
# hello

# %%
#for loops
seq=[0,1,2]
for item in seq:
    print(item)
# Out:
# 0
# 1
# 2

# %%
seq=['hi','hello','bye']
for words in seq:
    print(words)
# Out:
# hi
# hello
# bye

# %%
dictionary={'key':20,'key2':30,'key3':40,'key4':50}
for things in dictionary:
    print(dictionary[things])
# Out:
# 20
# 30
# 40
# 50

# %%
#while luups
i=1
while i<5:
    print('i is currently {}'.format(i))
    i+=1
# Out:
# i is currently 1
# i is currently 2
# i is currently 3
# i is currently 4

# %%
#range
range(5)
# Out:
# range(0, 5)

# %%
for i in range(0,5,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
#list comprehension
x=[0,1,2,3]

# %%
out=[]
for i in x:
    out.append(i**2)
out
# Out:
# [0, 1, 4, 9]

# %%
#list comprehension
out=[i**2 for i in x]
out
# Out:
# [0, 1, 4, 9]

# %%
def  my_func(p=1):
    """Doc string idhar likh!"""
    print(p)
my_func(5)
# Out:
# 5

# %%
def new_func(p='enter an argument'):
    return p*5
x=new_func(8)
x
# Out:
# 40

# %%
#lambda expression 
lambda new_fun:new_fun*5
# Out:
# <function __main__.<lambda>(new_fun)>

# %%
seq=[1,2,3,4,5]
list(map(new_func,seq))
# Out:
# [5, 10, 15, 20, 25]

# %%
seq=[0,1,2,3,4,5]
list(map(lambda new_fun:new_fun*5,seq))
# Out:
# [0, 5, 10, 15, 20, 25]

# %%
def is_even(p):
    return p%2==0
list(filter(is_even,seq))
# Out:
# [0, 2, 4]

# %%
list(filter(lambda is_even:is_even%2==0,seq))
# Out:
# [0, 2, 4]

# %%
#methods
st='Hello hum CBI se hai'
st.lower()
# Out:
# 'hello hum cbi se hai'

# %%
st.upper()
# Out:
# 'HELLO HUM CBI SE HAI'

# %%
tweet='Chalen ghoomne? Bolo'
tweet.split()
# Out:
# ['Chalen', 'ghoomne?', 'Bolo']

# %%
tweet.split('?')[1]
# Out:
# ' Bolo'

# %%
dictionary
# Out:
# {'key': 20, 'key2': 30, 'key3': 40, 'key4': 50}

# %%
dictionary.keys()
# Out:
# dict_keys(['key', 'key2', 'key3', 'key4'])

# %%
dictionary.items()
# Out:
# dict_items([('key', 20), ('key2', 30), ('key3', 40), ('key4', 50)])

# %%
my_list
# Out:
# ['watermelon', 1, 2, 3, 4, 5]

# %%
my_list
# Out:
# ['watermelon', 1, 2, 3, 4, 5]

# %%
my_list.pop(0)
# Out:
# 'watermelon'

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]
